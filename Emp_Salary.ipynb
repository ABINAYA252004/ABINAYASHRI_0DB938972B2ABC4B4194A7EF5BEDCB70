# %% [markdown]
# <a href="https://colab.research.google.com/github/ABINAYA252004/ABINAYASHRI_0DB938972B2ABC4B4194A7EF5BEDCB70/blob/main/Emp_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Employee_Salary_Prediction_Dataset (1) (2).csv')

# %%
df
# Out:
#   Emp_ID           Name  Age                Email  Working_Days  Present_Days  \
# 0  E1001   Rajesh Kumar   58  rajesh@technova.com             0             0
# 1  E1002     Sneha Iyer   54   sneha@technova.com             0             0
# 2  E1003    Deepak Nair   52  deepak@technova.com             0             0
# 3  E1004  Kavita Sharma   49  kavita@technova.com            26            23
# 4  E1005    Arjun Mehta   50   arjun@technova.com            25            23
# 5  E1006    Priya Singh   36   priya@technova.com            22            20
# 6  E1007     Anil Verma   53    anil@technova.com            26            23
# 7  E1008      Rekha Das   49   rekha@technova.com            25            21
# 8  E1009   Manoj Pillai   51   manoj@technova.com            23            21
#
#    Avg_Work_Hours  Salary (?)  Attendance (%)  Hike (%)  Final_Salary (?)
# 0             0.0       56000            0.00        10             61600
# ...

# %%
df=df.drop([0,1,2])

# %%
df
# Out:
#   Emp_ID           Name  Age                Email  Working_Days  Present_Days  \
# 3  E1004  Kavita Sharma   49  kavita@technova.com            26            23
# 4  E1005    Arjun Mehta   50   arjun@technova.com            25            23
# 5  E1006    Priya Singh   36   priya@technova.com            22            20
# 6  E1007     Anil Verma   53    anil@technova.com            26            23
# 7  E1008      Rekha Das   49   rekha@technova.com            25            21
# 8  E1009   Manoj Pillai   51   manoj@technova.com            23            21
#
#    Avg_Work_Hours  Salary (?)  Attendance (%)  Hike (%)  Final_Salary (?)
# 3             9.3       55000           88.46        30             71500
# 4             8.8       60000           92.00        30             78000
# 5             9.1       47000           90.90        30             61100
# 6             8.9       65000           88.46        30             84500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 3 to 8
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Emp_ID            6 non-null      object
#  1   Name              6 non-null      object
#  2   Age               6 non-null      int64
#  3   Email             6 non-null      object
#  4   Working_Days      6 non-null      int64
#  5   Present_Days      6 non-null      int64
#  6   Avg_Work_Hours    6 non-null      float64
#  7   Salary (?)        6 non-null      int64
#  8   Attendance (%)    6 non-null      float64
#  9   Hike (%)          6 non-null      int64
#  10  Final_Salary (?)  6 non-null      int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 660.0+ bytes

# %%
df.drop(columns=['Emp_ID', 'Name', 'Age', 'Email'],inplace=True)

# %%
x=df.drop(columns=['Final_Salary (?)'])
y=df['Final_Salary (?)']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([84500, 78000])

# %%
from sklearn.metrics import accuracy_score
accuracy = model.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5

# %%
import pickle

# %%
with open('model.csv','wb') as f:
  pickle.dump(model,f)

# %%
with open('model.csv','rb') as f:
  model_loaded=pickle.load(f)

# %%
import joblib

# %%
features=[ 'Working_Days', 'Present_Days',
       'Avg_Work_Hours', 'Salary (?)', 'Attendance (%)', 'Hike (%)']
new_data={'Working_Days':25,'Present_Days':25,'Avg_Work_Hours':9,'Salary (?)':60000,'Attendance (%)':100.0,'Hike (%)':30}

# %%
df = pd.DataFrame([new_data])

# %%
df.columns
# Out:
# Index(['Working_Days', 'Present_Days', 'Avg_Work_Hours', 'Salary (?)',
#        'Attendance (%)', 'Hike (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Working_Days    1 non-null      int64
#  1   Present_Days    1 non-null      int64
#  2   Avg_Work_Hours  1 non-null      int64
#  3   Salary (?)      1 non-null      int64
#  4   Attendance (%)  1 non-null      float64
#  5   Hike (%)        1 non-null      int64
# dtypes: float64(1), int64(5)
# memory usage: 180.0 bytes

# %%
df
# Out:
#    Working_Days  Present_Days  Avg_Work_Hours  Salary (?)  Attendance (%)  \
# 0            25            25               9       60000           100.0
#
#    Hike (%)
# 0        30

# %%
model = joblib.load("/content/model.csv")

# %%
prediction = model.predict(df)
print("Prediction:", prediction[0])
# Out:
# Prediction: 84500
